# %% [markdown]
# # Econ 425T Homework 1

# %% [markdown]
# AUTHOR：Ruoxuan Yan
#
# UID: 506082695

# %% [markdown]
# ## 1.Filling gaps in lecture notes

# %% [markdown]
# ### 1.1 Optimal regression function

# %% [markdown]
# $\begin{aligned}
# \operatorname{E}[Y - \hat f(X)]^2 &= \operatorname{E}[f(X) + \varepsilon - \hat f(X)]^2 \\
# &= \operatorname{E}[(f(X) - \hat f(X))^2] + \operatorname{E}[\varepsilon^2] + 2\operatorname{E}[\varepsilon(f(X) - \hat f(X))]
# \end{aligned}$
#
# Because: \
# $\begin{aligned}
# \operatorname{E}[\varepsilon(f(X) - \hat f(X))] &=
# \operatorname{E}[\operatorname{E}[\varepsilon(f(X) - \hat f(X))]|X] \\
# &= \operatorname{E}[\operatorname{E}[\varepsilon|X](f(X) - \hat f(X))] \\
# &= 0
# \end{aligned}$
#
# And $\operatorname{E}[\varepsilon^2]$ is a constant number.
#
# When $\hat f(X) = \operatorname{E}[Y|X] = \operatorname{E}[f(X) + \varepsilon|X] = f(X)$, $\operatorname{E}[(f(X) - \hat f(X))^2]$ arrives the minimum value $0$ and mean squared prediction error arrives the minimum value $\operatorname{E}[\varepsilon^2]$.

# %% [markdown]
# ### 1.2 Bias-variance trade-off

# %% [markdown]
# $\begin{aligned}
# \operatorname{E}[y_0 - \hat f(x_0)]^2 &= \operatorname{E}[f(x_0) + \varepsilon - \hat f(x_0)]^2 \\
# &= \operatorname{E}[(f(x_0) - \hat f(x_0))^2] + \operatorname{E}[\varepsilon^2] + 2\operatorname{E}[\varepsilon(f(x_0) - \hat f(x_0))] \\
# &= \operatorname{E}[(f(x_0) - \hat f(x_0))^2] + \operatorname{Var}[\varepsilon] + 0
# \end{aligned}$
#
# Because: \
# $\begin{aligned}
# \operatorname{E}[(f(x_0) - \hat f(x_0))^2] &= \operatorname{E}[(f(x_0) - \operatorname{E}[\hat f(x_0)] + \operatorname{E}[\hat f(x_0)] - \hat f(x_0))^2] \\
# &= \operatorname{E}[(f(x_0) - \operatorname{E}[\hat f(x_0)])^2] + \operatorname{E}[(\operatorname{E}[\hat f(x_0)] - \hat f(x_0))^2] + \\
# &\operatorname{E}[(f(x_0) - \operatorname{E}[\hat f(x_0)])(\operatorname{E}[\hat f(x_0)] - \hat f(x_0))] \\
# & = \operatorname{E}[(f(x_0) - \operatorname{E}[\hat f(x_0)])^2] + \operatorname{E}[(\operatorname{E}[\hat f(x_0)] - \hat f(x_0))^2] + 0\\
# &= [\operatorname{Bias}(\hat f(x_0))]^2 + \operatorname{Var}(\hat f(x_0))
# \end{aligned}$
#
# We can get: \
# $\operatorname{E}[y_0 - \hat f(x_0)]^2 = \operatorname{Var}(\hat f(x_0)) + [\operatorname{Bias}(\hat f(x_0))]^2 + \operatorname{Var}(\varepsilon)$

# %% [markdown]
# ## 2. ISL Exercise 2.4.3

# %% [markdown]
# ### (a)

# %% [markdown]
# ![2_a.jpeg](attachment:2_a.jpeg)

# %% [markdown]
# ### (b)

# %% [markdown]
# 1. test error: The test error decreases first and then increases with flexibility and shows the U-shape. Because when the flexibility of the model increases, it can contain more information about the training data so when applied to the test data the test error decreases. But when flexibility increases too much, it will contain more noise and generating overfitting problem so the test error increases.
#
# 2. training error: The more flexible the curve is, the better it can fit the training data, so the training error will be reduced.
#
# 3. Bayes error: Because the irreducible error is not correlated with the model flexibility, it will not change.
#
# 4. variance: Because the flexibility increases, the model complexity increases. So the model changes more if applied to a different training dataset. So model variance will increase.
#
# 5. typical bias: When the model complexity increases, it contains more information, so the expected value of the model will be closer to the real value and the typical bias decreases.

# %% [markdown]
# ## 3. ISL Exercise 2.4.4

# %% [markdown]
# ### (a)

# %% [markdown]
# 1. Whether the stock price will go up or down in the next date. The response is up or down, the predictors are prices in previous date, macro economic indicators, etc. The goal is prediction.
#
# 2. Whether an email is junk mail. The response is true or false, the predictors are the content of the email. The goal is prediction.
#
# 3. Classify defferent bank customers into different credit level. The response is different credit level, the predictors are customers characteristics like their annual income, job type, credit history, etc. The goal is prediction.

# %% [markdown]
# ### (b)

# %% [markdown]
# 1. Analyzing the influence of gender on income. The response is income, the predictors are gender, education, age, etc. The goal is inference.
#
# 2. Analyzing the relationship between advertising expense and sales. The response is sales, the predictors are advertising expense, size of the company, price of the product, etc. The goal is inference.
#
# 3. Analyzing the relationship between height and the amount of milk drank. The response is height, the predictors are the amount of milk drank, father's and mother's height, etc. The goal is inference.

# %% [markdown]
# ### (c)

# %% [markdown]
# 1. Divide loans into different rating levels. The predictors are the revenue, property, reputation, etc. of the loan issuer.
#
# 2. Divide video app users into different groups and make recommendations based on similar behaviors. The predictors are number of different type of videos whatched, time to use the app, length of different type of videos whatched, etc.
#
# 3. Divide animals into different classes. The predictors are animal appearance, behaviors, generic composition, etc.

# %% [markdown]
# ## 4. ISL Exercise 2.4.10

# %% [markdown]
# ### (a)

# %%
import pandas as pd
import io
import requests
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/ucla-econ-425t/2023winter/master/slides/data/Boston.csv"
s = requests.get(url).content
Boston = pd.read_csv(io.StringIO(s.decode('utf-8')), index_col = 0)
Boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 1    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 2    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 3    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 4    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 5    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 1       15.3   4.98  24.0
# 2       17.8   9.14  21.6
# 3       17.8   4.03  34.7
# ...

# %% [markdown]
# There are 506 rows and 13 columns in this data set. The rows represent an observation of the population and the columns represent different features.

# %% [markdown]
# ### (b)

# %%
# Make the pair plot
sns.pairplot(data = Boston)

# %% [markdown]
# Variables like rm, age, dis, etc. seem to have a strong correlation with crime rate.
#
# Among all the predictors, there are also strong correlations exist between variables like lstat and rm, medv and rm, dis and nox, etc.

# %% [markdown]
# ### (c)

# %%
corr_crime = pd.DataFrame()
for i in range(1,len(Boston.columns)):
    row = pd.DataFrame([[Boston.columns[0], Boston.columns[i], Boston['crim'].corr(Boston[Boston.columns[i]])]])
    corr_crime = pd.concat([corr_crime, row])
    
print(corr_crime)
# Out:
#       0        1         2
# 0  crim       zn -0.200469
# 0  crim    indus  0.406583
# 0  crim     chas -0.055892
# 0  crim      nox  0.420972
# 0  crim       rm -0.219247
# 0  crim      age  0.352734
# 0  crim      dis -0.379670
# 0  crim      rad  0.625505
# 0  crim      tax  0.582764
# 0  crim  ptratio  0.289946
# 0  crim    lstat  0.455621
# 0  crim     medv -0.388305

# %% [markdown]
# From the pairwise scatterplots in part (b) and correlation coefficient table above, we can see that variables like nox (nitrogen oxides concentration), rm (average number of rooms per dwelling), age (proportion of owner-occupied units built prior to 1940), dis (weighted mean of distances to five Boston employment centres), lstat (lower status of the population (percent)) and medv (median value of owner-occupied homes in $1000s) seem to have a strong association with per capita crime rate.
#
# When nox, age and lstat increase, crime rate tends to increase. When rm, dis and medv increase, crime rate tends to decrease.

# %% [markdown]
# ### (d)

# %%
Boston['crim'].describe()
# Out:
# count    506.000000
# mean       3.613524
# std        8.601545
# min        0.006320
# 25%        0.082045
# 50%        0.256510
# 75%        3.677083
# max       88.976200
# Name: crim, dtype: float64

# %%
plt.subplot(1,2,1)
sns.histplot(Boston['crim'])
plt.subplot(1,2,2)
sns.boxplot(Boston['crim'])
# Out:
# /Users/ireneyan/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='crim'>

# %%
Boston['tax'].describe()
# Out:
# count    506.000000
# mean     408.237154
# std      168.537116
# min      187.000000
# 25%      279.000000
# 50%      330.000000
# 75%      666.000000
# max      711.000000
# Name: tax, dtype: float64

# %%
plt.subplot(1,2,1)
sns.histplot(Boston['tax'])
plt.subplot(1,2,2)
sns.boxplot(Boston['tax'])
# Out:
# /Users/ireneyan/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tax'>

# %%
Boston['ptratio'].describe()
# Out:
# count    506.000000
# mean      18.455534
# std        2.164946
# min       12.600000
# 25%       17.400000
# 50%       19.050000
# 75%       20.200000
# max       22.000000
# Name: ptratio, dtype: float64

# %%
plt.subplot(1,2,1)
sns.histplot(Boston['ptratio'])
plt.subplot(1,2,2)
sns.boxplot(Boston['ptratio'])
# Out:
# /Users/ireneyan/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ptratio'>

# %% [markdown]
# From the analysis above, there are census tracts of Boston appear to have particularly high crime rates because the max value is much larger than other percentile. The tax rates and pupil-teacher ratios do not seems to have particularly high values.
#
# The range of crime rates is very large and have extreme values. The range of tax and ptratio are not large and there are not many extreme values.

# %% [markdown]
# ### (e)

# %%
n = len(Boston[Boston['chas'] == 1].chas)
print(n)
# Out:
# 35

# %% [markdown]
# There are 35 of the census tracts in this data set bound the Charles river.

# %% [markdown]
# ### (f)

# %%
np.median(Boston['ptratio'])
# Out:
# 19.05

# %% [markdown]
# The median pupil-teacher ratio among the towns in this data set is 19.05.

# %% [markdown]
# ### (g)

# %%
Boston[Boston['medv'] == np.min(Boston['medv'])]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 399  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 406  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 399     20.2  30.59   5.0
# 406     20.2  22.98   5.0

# %%
Boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# The number 399 and 406 census tract of Boston has lowest median value of owner-occupied homes.
#
# The values of the other predictors for that census tract are shown on the table above. $crim$, $indus$, $nox$, $age$, $rad$, $tax$, $ptratio$, $lstat$ are very high compare to the overall ranges for those predictors. $zn$, $dis$ are very low compare to the overall ranges for those predictors.
#
# The result shows that these two census tracts of Boston with the lowest median value of owner-occupied homes are the least desirable places to live. They have the worst living conditions.

# %% [markdown]
# ### (h)

# %%
print(len(Boston[Boston['rm'] > 7]))
print(len(Boston[Boston['rm'] > 8]))
# Out:
# 64
# 13

# %% [markdown]
# There are 64 census tracts average more than seven rooms per dwelling and 13 more than eight rooms per dwelling.

# %%
Boston[Boston['rm'] > 8].describe()
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio      lstat  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000  13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538   4.310000
# std    24.608723   1.883955   5.332532  110.971063   2.410580   1.373566
# ...

# %% [markdown]
# For those who have more than eight rooms per dwelling, they have relatively low crime rate and better living conditions.

# %% [markdown]
# ## 5. ISL Exercise 3.7.3

# %% [markdown]
# ### (a)

# %% [markdown]
# iii is correct. Because the coefficient of $Level$ can be written as $\beta_3 + \beta_5GPA$. Plug into the number this becomes $35 - 10GPA$. When GPA is above $3.5$, this coefficient will be negative which means college graduates earn less, on average, than high school graduates.

# %% [markdown]
# ### (b)

# %% [markdown]
# $\widehat {salary} = 50 + 20*4.0 + 0.07*110 + 35*1 + 0.01*4.0*110 - 10*4.0*1 = 137.1$
# So the prediction of the salary of a college graduate is $137100\$$.

# %% [markdown]
# ### (c)

# %% [markdown]
# False. Because the value of the coefficient has nothing to do with the evidence of an interaction effect. The evidence is determined by the significant level of the coefficient instead of the value of the coefficient. So we need the t-statistics or the p-value of the coefficient to determine if there is any evidence of an interaction effect.

# %% [markdown]
# ## 6. ISL Exercise 3.7.15

# %% [markdown]
# ### (a)

# %%
import statsmodels.formula.api as smf

columns = Boston.columns.difference(['crim'])
slr_coeff = [
    smf.ols(formula = 'crim ~ ' + col, data = Boston).fit().params[1]
    for col in columns
    ]
slr_se = [
    smf.ols(formula = 'crim ~ ' + col, data = Boston).fit().bse[1]
    for col in columns
    ]
slr_t = [
    smf.ols(formula = 'crim ~ ' + col, data = Boston).fit().tvalues[1]
    for col in columns
    ]
slr_p = [
    smf.ols(formula = 'crim ~ ' + col, data = Boston).fit().pvalues[1]
    for col in columns
    ]
slr_result = pd.DataFrame({'Betahat': slr_coeff, 'std error': slr_se,
                          't': slr_t, 'p-value': slr_p}, index = columns)
slr_result
# Out:
#            Betahat  std error          t       p-value
# age       0.107786   0.012736   8.462825  2.854869e-16
# chas     -1.892777   1.506115  -1.256727  2.094345e-01
# dis      -1.550902   0.168330  -9.213458  8.519949e-19
# indus     0.509776   0.051024   9.990848  1.450349e-21
# lstat     0.548805   0.047761  11.490654  2.654277e-27
# medv     -0.363160   0.038390  -9.459710  1.173987e-19
# nox      31.248531   2.999190  10.418989  3.751739e-23
# ptratio   1.151983   0.169374   6.801430  2.942922e-11
# rad       0.617911   0.034332  17.998199  2.693844e-56
# rm       -2.684051   0.532041  -5.044819  6.346703e-07
# tax       0.029742   0.001847  16.099388  2.357127e-47
# zn       -0.073935   0.016095  -4.593776  5.506472e-06

# %% [markdown]
# Because all the p-values of the simple linear regression coefficient except for $chas$ are smaller than 0.05, there is a statistically significant association between the predictors except for $chas$ and the response.

# %%
fig, axes = plt.subplots(3, 4, figsize = (20, 15),sharey=True)
for i in range(3):
    for j in range(4):
        sns.regplot(x=Boston[columns[(i)*4+j]],y=Boston['crim'], 
                    scatter_kws = {'alpha' : 0.3},
                    line_kws = {"color":"orange"},lowess = True,ax = axes[i,j])
# Out:
# /Users/ireneyan/opt/anaconda3/lib/python3.9/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in true_divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# /Users/ireneyan/opt/anaconda3/lib/python3.9/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in true_divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),

# %% [markdown]
# From the scatter plots and lowess lines, we can see there is a statistically significant association between the predictors except for $chas$ and the response.

# %% [markdown]
# ### (b)

# %%
mlr_reg = smf.ols(formula = 'crim ~ ' + '+'.join(columns), data = Boston).fit()
mlr_result = mlr_reg.summary()
mlr_result
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.436
# Method:                 Least Squares   F-statistic:                     33.52
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):           2.03e-56
# Time:                        16:37:25   Log-Likelihood:                -1655.4
# No. Observations:                 506   AIC:                             3337.
# Df Residuals:                     493   BIC:                             3392.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.7784      7.082      1.946      0.052      -0.136      27.693
# ...

# %% [markdown]
# The result is shown on the table above and it shows that strong multicollinearity problem exists. For $dis$, $medv$, $rad$ and $zn$ we can reject the null hypothesis $H_0 : β_j = 0$, because their p-value is less than 0.05.

# %% [markdown]
# ### (c)

# %%
mlr_coeff = [mlr_reg.params[i] for i in range(1,len(Boston.columns))]
mlr_coeff
# Out:
# [-0.0008482790661908792,
#  -0.8253775522410041,
#  -1.0122467382083942,
#  -0.05835011066598176,
#  0.13880059677676118,
#  -0.22005635903920368,
#  -9.957586547089257,
#  -0.3040727572312298,
#  0.6124653114967993,
#  0.6289106621782001,
#  -0.00377564652344227,
#  0.045710038639755896]

# %%
plt.scatter(slr_coeff, mlr_coeff)
plt.xlabel("Univariate Regression coefficients") 
plt.ylabel("Multiple Regression coefficients") 
plt.show()

# %% [markdown]
# The results from (a) and (b) are very different because they are not on the 45 degree line. For example, the coefficient of nox changes from 31 to -10.

# %% [markdown]
# ### (d)

# %%
nlr_coeff1 = [
    smf.ols(formula = 'crim ~ ' + col + '+ I(' +col+ '**2)' + '+ I(' +col+ '**3)', 
            data = Boston).fit().params[1]
    for col in columns
    ]
nlr_coeff2 = [
    smf.ols(formula = 'crim ~ ' + col + '+ I(' +col+ '**2)' + '+ I(' +col+ '**3)', 
            data = Boston).fit().params[2]
    for col in columns
    ]
nlr_coeff3 = [
    smf.ols(formula = 'crim ~ ' + col + '+ I(' +col+ '**2)' + '+ I(' +col+ '**3)', 
            data = Boston).fit().params[3]
    for col in columns
    ]
nlr_p1 = [
    smf.ols(formula = 'crim ~ ' + col + '+ I(' +col+ '**2)' + '+ I(' +col+ '**3)', 
            data = Boston).fit().pvalues[1]
    for col in columns
    ]
nlr_p2 = [
    smf.ols(formula = 'crim ~ ' + col + '+ I(' +col+ '**2)' + '+ I(' +col+ '**3)', 
            data = Boston).fit().pvalues[2]
    for col in columns
    ]
nlr_p3 = [
    smf.ols(formula = 'crim ~ ' + col + '+ I(' +col+ '**2)' + '+ I(' +col+ '**3)', 
            data = Boston).fit().pvalues[3]
    for col in columns
    ]
nlr_result = pd.DataFrame({'Betahat1': nlr_coeff1, 'p-value1': nlr_p1, 
                           'Betahat2': nlr_coeff2, 'p-value2': nlr_p2,
                           'Betahat3': nlr_coeff3, 'p-value3': nlr_p3}, index = columns)
nlr_result
# Out:
#             Betahat1      p-value1     Betahat2      p-value2      Betahat3  \
# age         0.273653  1.426608e-01    -0.007230  4.737733e-02  5.745307e-05
# chas       -0.630926  2.094345e-01    -0.630926  2.094345e-01 -6.309255e-01
# dis       -15.554353  6.374792e-18     2.452072  4.941214e-12 -1.185986e-01
# indus      -1.965213  5.297064e-05     0.251937  3.420187e-10 -6.976009e-03
# lstat      -0.449066  3.345300e-01     0.055779  6.458736e-02 -8.573703e-04
# medv       -5.094831  2.637707e-28     0.155496  3.260523e-18 -1.490103e-03
# nox     -1279.371252  2.758372e-13  2248.544053  6.811300e-15 -1.245703e+03
# ptratio   -82.360538  3.028663e-03     4.635347  4.119552e-03 -8.476032e-02
# rad         0.512736  6.234175e-01    -0.075177  6.130099e-01  3.208996e-03
# rm        -39.150136  2.117564e-01     4.550896  3.641094e-01 -1.744770e-01
# tax        -0.153310  1.097075e-01     0.000361  1.374682e-01 -2.203715e-07
# ...

# %% [markdown]
# The p-value of the coefficients for the square of the predictors and the predictors to the power of three are all significant for $age$, $dis$, $indus$, $medv$, $nox$ and $ptratio$. So there is evidence of non-linear association between the response and these predictors.

# %% [markdown]
# ## 7. Bonus question

# %% [markdown]
# $\begin{aligned}
# R^2 &= 1 - \frac{\text{RSS}}{\text{TSS}} = \frac{\text{ESS}}{\text{TSS}} = \frac{\operatorname{Var}[\hat{\mathbf{y}}]}{\operatorname{Var}[\mathbf{y}]} \\
# [\operatorname{Cor}(\mathbf{y}, \hat{\mathbf{y}})]^2 &= \frac{\operatorname{Cov}(\mathbf{y}, \hat{\mathbf{y}})^2}{\operatorname{Var}[\mathbf{y}]\operatorname{Var}[\hat{\mathbf{y}}]} \\
# \operatorname{Cov}(\mathbf{y}, \hat{\mathbf{y}}) &= \operatorname{Cov}(\hat{\mathbf{y}}, \hat{\mathbf{y}} + \mathbf{\hat{u}}) \\
# &= \operatorname{Cov}(\hat{\mathbf{y}}, \hat{\mathbf{y}}) + \operatorname{Cov}(\hat{\mathbf{y}}, \mathbf{\hat{u}}) \\
# &= \operatorname{Cov}(\hat{\mathbf{y}}, \hat{\mathbf{y}}) + 0 \\
# &= \operatorname{Var}(\hat{\mathbf{y}}) \\
# [\operatorname{Cor}(\mathbf{y}, \hat{\mathbf{y}})]^2 &= \frac{\operatorname{Var}[\hat{\mathbf{y}}]}{\operatorname{Var}[\mathbf{y}]}
# \end{aligned}$
#
# So $R^2 = [\operatorname{Cor}(\mathbf{y}, \hat{\mathbf{y}})]^2$.
